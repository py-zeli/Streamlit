# %%
import requests
import time
import random

# URL do seu endpoint Flask para receber coordenadas
URL_ENDPOINT = "http://127.0.0.1:5000/nova-coordenada"

# Lista de coordenadas aproximadas de grandes cidades do Brasil
CIDADES = {
    "São Paulo": (-23.5505, -46.6333),
    "Rio de Janeiro": (-22.9068, -43.1729),
    "Brasília": (-15.7797, -47.9297),
    "Salvador": (-12.9777, -38.5016),
    "Fortaleza": (-3.7319, -38.5267),
    "Belo Horizonte": (-19.9167, -43.9345),
    "Manaus": (-3.1190, -60.0217),
    "Curitiba": (-25.4284, -49.2733),
    "Recife": (-8.0578, -34.8824),
    "Porto Alegre": (-30.0346, -51.2177),
    "Belém": (-1.4558, -48.5035)
}

# Loop infinito para enviar requisições
while True:
    try:
        # Escolhe uma cidade aleatoriamente da lista
        nome_cidade, coords_cidade = random.choice(list(CIDADES.items()))

        # Gera uma coordenada ligeiramente aleatória próxima à cidade
        latitude_aleatoria = coords_cidade[0] + random.uniform(-0.5, 0.5)
        longitude_aleatoria = coords_cidade[1] + random.uniform(-0.5, 0.5)

        # Dados a serem enviados no corpo da requisição
        dados = {
            "latitude": latitude_aleatoria,
            "longitude": longitude_aleatoria
        }

        # Envia a requisição POST para o servidor Flask
        response = requests.post(URL_ENDPOINT, json=dados)

        # Verifica se a requisição foi bem-sucedida
        if response.status_code == 200:
            print(f"Requisição enviada com sucesso para: {nome_cidade} ({latitude_aleatoria:.4f}, {longitude_aleatoria:.4f})")
        else:
            print(f"Erro ao enviar requisição. Código de status: {response.status_code}")
            print(f"Resposta do servidor: {response.text}")

    except requests.exceptions.RequestException as e:
        print(f"Erro de conexão: {e}")
        
    # Espera 1 segundo antes de enviar a próxima requisição
    time.sleep(0.05)
# Out:
# Requisição enviada com sucesso para: Salvador (-13.4203, -38.6074)
# Requisição enviada com sucesso para: Salvador (-13.4032, -38.0323)
# Requisição enviada com sucesso para: Rio de Janeiro (-22.9300, -43.6375)
# Requisição enviada com sucesso para: Recife (-7.9948, -35.1123)
# Requisição enviada com sucesso para: Recife (-8.1615, -35.1921)
# Requisição enviada com sucesso para: São Paulo (-23.4784, -46.2998)
# Requisição enviada com sucesso para: Fortaleza (-3.4449, -39.0206)
# Requisição enviada com sucesso para: Salvador (-12.5615, -38.4317)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.1602, -43.5998)
# Requisição enviada com sucesso para: Belo Horizonte (-19.6720, -43.7492)
# Requisição enviada com sucesso para: Manaus (-3.0499, -60.4082)
# Requisição enviada com sucesso para: Belém (-1.9105, -48.8336)
# Requisição enviada com sucesso para: Brasília (-15.9666, -47.9795)
# Requisição enviada com sucesso para: Curitiba (-25.8444, -49.4811)
# Requisição enviada com sucesso para: Rio de Janeiro (-22.4125, -42.8716)
# Requisição enviada com sucesso para: Brasília (-15.5161, -47.5295)
# Requisição enviada com sucesso para: Curitiba (-25.1626, -49.4592)
# Requisição enviada com sucesso para: Brasília (-16.1523, -47.6275)
# Requisição enviada com sucesso para: Belém (-0.9932, -48.8937)
# Requisição enviada com sucesso para: Salvador (-12.9659, -38.0372)
# Requisição enviada com sucesso para: Salvador (-12.7287, -38.7256)
# Requisição enviada com sucesso para: Fortaleza (-3.7928, -38.3239)
# Requisição enviada com sucesso para: Belém (-1.1525, -48.3300)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.3107, -43.5462)
# Requisição enviada com sucesso para: Curitiba (-25.0776, -48.8040)
# Requisição enviada com sucesso para: Salvador (-12.7921, -38.6210)
# Requisição enviada com sucesso para: Salvador (-12.7097, -38.7420)
# Requisição enviada com sucesso para: Curitiba (-25.2240, -49.4628)
# Requisição enviada com sucesso para: Fortaleza (-3.7919, -38.8262)
# Requisição enviada com sucesso para: Belo Horizonte (-19.9059, -43.9884)
# Requisição enviada com sucesso para: Recife (-8.2481, -35.2232)
# Requisição enviada com sucesso para: Porto Alegre (-30.2478, -50.9996)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.3361, -43.5828)
# Requisição enviada com sucesso para: Brasília (-16.2181, -47.9600)
# Requisição enviada com sucesso para: Salvador (-12.8613, -38.0946)
# Requisição enviada com sucesso para: Rio de Janeiro (-22.5827, -43.0120)
# Requisição enviada com sucesso para: Curitiba (-24.9905, -49.5550)
# Requisição enviada com sucesso para: Belo Horizonte (-19.5720, -43.5048)
# Requisição enviada com sucesso para: Belo Horizonte (-19.7394, -43.9215)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.2166, -43.1402)
# Requisição enviada com sucesso para: Curitiba (-25.0789, -48.8857)
# Requisição enviada com sucesso para: Curitiba (-25.0621, -49.7718)
# Requisição enviada com sucesso para: Belo Horizonte (-20.1467, -43.4441)
# Requisição enviada com sucesso para: Belo Horizonte (-19.4173, -44.1048)
# Requisição enviada com sucesso para: Belo Horizonte (-19.5339, -44.2965)
# Requisição enviada com sucesso para: Manaus (-2.8469, -60.1606)
# Requisição enviada com sucesso para: Belém (-1.5686, -48.2253)
# Requisição enviada com sucesso para: Belo Horizonte (-20.2859, -43.5404)
# Requisição enviada com sucesso para: Brasília (-16.2061, -48.2080)
# Requisição enviada com sucesso para: Curitiba (-25.1842, -49.1706)
# Requisição enviada com sucesso para: Porto Alegre (-30.2639, -51.0658)
# Requisição enviada com sucesso para: Recife (-7.6407, -35.3338)
# Requisição enviada com sucesso para: Recife (-8.1365, -35.0622)
# Requisição enviada com sucesso para: Brasília (-15.7981, -48.1947)
# Requisição enviada com sucesso para: Belém (-1.7637, -48.7974)
# Requisição enviada com sucesso para: Rio de Janeiro (-22.9734, -42.9693)
# Requisição enviada com sucesso para: Belo Horizonte (-19.8684, -43.6656)
# Requisição enviada com sucesso para: Belo Horizonte (-20.2979, -43.5116)
# Requisição enviada com sucesso para: Recife (-8.4054, -35.3547)
# Requisição enviada com sucesso para: Recife (-7.7321, -34.8823)
# Requisição enviada com sucesso para: São Paulo (-23.9674, -47.0058)
# Requisição enviada com sucesso para: Recife (-7.6353, -35.2666)
# Requisição enviada com sucesso para: Belém (-0.9575, -48.2937)
# Requisição enviada com sucesso para: Salvador (-12.9910, -38.5997)
# Requisição enviada com sucesso para: São Paulo (-23.8058, -46.6289)
# Requisição enviada com sucesso para: Manaus (-3.4145, -59.7668)
# Requisição enviada com sucesso para: Curitiba (-25.2881, -49.5053)
# Requisição enviada com sucesso para: Salvador (-12.7550, -38.4565)
# Requisição enviada com sucesso para: Fortaleza (-3.7573, -38.0340)
# Requisição enviada com sucesso para: Recife (-8.4858, -34.4895)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.3367, -43.1820)
# Requisição enviada com sucesso para: Recife (-7.7291, -34.7654)
# Requisição enviada com sucesso para: Manaus (-2.7943, -59.8676)
# Requisição enviada com sucesso para: Salvador (-12.6418, -38.6833)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.0929, -43.0104)
# Requisição enviada com sucesso para: Belém (-1.5510, -48.2926)
# Requisição enviada com sucesso para: Belo Horizonte (-20.1668, -44.2814)
# Requisição enviada com sucesso para: São Paulo (-23.8414, -46.9934)
# Requisição enviada com sucesso para: Curitiba (-25.0205, -48.7855)
# Requisição enviada com sucesso para: Belém (-1.9333, -48.8980)
# Requisição enviada com sucesso para: Belo Horizonte (-20.2017, -44.1813)
# Requisição enviada com sucesso para: Recife (-7.6783, -34.9792)
# Requisição enviada com sucesso para: Belo Horizonte (-19.9230, -43.9242)
# Requisição enviada com sucesso para: Salvador (-13.2254, -38.7085)
# Requisição enviada com sucesso para: Porto Alegre (-29.6315, -51.1279)
# Requisição enviada com sucesso para: Brasília (-16.1538, -47.4443)
# Requisição enviada com sucesso para: Manaus (-2.8561, -59.8730)
# Requisição enviada com sucesso para: Fortaleza (-3.9605, -38.1287)
# Requisição enviada com sucesso para: Belém (-1.2705, -48.1727)
# Requisição enviada com sucesso para: Belém (-1.5121, -48.2578)
# Requisição enviada com sucesso para: Fortaleza (-3.3699, -38.1678)
# Requisição enviada com sucesso para: Fortaleza (-4.1501, -38.1170)
# Requisição enviada com sucesso para: Porto Alegre (-30.1473, -50.9787)
# Requisição enviada com sucesso para: Manaus (-3.3201, -59.7538)
# Requisição enviada com sucesso para: Rio de Janeiro (-23.0966, -42.9921)
# Requisição enviada com sucesso para: Rio de Janeiro (-22.9236, -42.7385)
# Requisição enviada com sucesso para: Manaus (-2.7492, -60.0888)
# Requisição enviada com sucesso para: São Paulo (-23.3717, -46.6981)
# Requisição enviada com sucesso para: São Paulo (-23.2280, -46.2853)
# Requisição enviada com sucesso para: Salvador (-13.4290, -38.6727)
# Requisição enviada com sucesso para: Recife (-7.6560, -34.5693)
# Requisição enviada com sucesso para: Salvador (-13.1861, -38.9277)
# Requisição enviada com sucesso para: Belo Horizonte (-20.3093, -44.3381)
# Requisição enviada com sucesso para: Fortaleza (-3.5568, -38.1522)
# Requisição enviada com sucesso para: São Paulo (-23.4332, -46.3093)
# Requisição enviada com sucesso para: Manaus (-3.0383, -60.4860)
# Requisição enviada com sucesso para: Curitiba (-25.6267, -49.6791)
# Requisição enviada com sucesso para: São Paulo (-23.8363, -46.3997)
# Requisição enviada com sucesso para: Salvador (-12.6781, -38.8951)
# Requisição enviada com sucesso para: Salvador (-12.5327, -38.4387)
# Requisição enviada com sucesso para: Belo Horizonte (-19.6669, -43.4468)
# Requisição enviada com sucesso para: Fortaleza (-3.5454, -38.7135)
# Requisição enviada com sucesso para: Fortaleza (-3.6782, -38.9510)
# Requisição enviada com sucesso para: Brasília (-16.2230, -47.9102)
# Requisição enviada com sucesso para: Brasília (-16.0236, -48.0744)
# Requisição enviada com sucesso para: Fortaleza (-3.3214, -39.0122)
# Requisição enviada com sucesso para: Salvador (-12.8611, -38.6283)
# Requisição enviada com sucesso para: Porto Alegre (-30.0363, -50.8496)
# Requisição enviada com sucesso para: Curitiba (-25.7636, -49.2163)
# Requisição enviada com sucesso para: Brasília (-16.1114, -47.8487)
# Requisição enviada com sucesso para: Rio de Janeiro (-22.4247, -43.3900)
# Requisição enviada com sucesso para: Recife (-8.1208, -35.0038)
# Requisição enviada com sucesso para: Porto Alegre (-30.2226, -51.1769)
# Requisição enviada com sucesso para: Brasília (-15.3909, -48.2828)
# Requisição enviada com sucesso para: Recife (-8.1549, -34.7727)
# Requisição enviada com sucesso para: Belém (-1.8709, -48.2001)
# Requisição enviada com sucesso para: Brasília (-15.8308, -47.7118)
# Requisição enviada com sucesso para: Manaus (-2.8066, -59.7865)
# Requisição enviada com sucesso para: Belo Horizonte (-19.6783, -43.7870)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 53
#      50     print(f"Erro de conexão: {e}")
#      52 # Espera 1 segundo antes de enviar a próxima requisição
# ---> 53 time.sleep(0.05)
#
# KeyboardInterrupt:
